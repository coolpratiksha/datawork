# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
covid = pd.read_csv('C:\Python\covid19_italy_province.csv')
covid.head()
# Out:
#    SNo                 Date Country  RegionCode RegionName  ProvinceCode  \
# 0    0  2020-02-24T18:00:00     ITA          13    Abruzzo            66
# 1    1  2020-02-24T18:00:00     ITA          13    Abruzzo            67
# 2    2  2020-02-24T18:00:00     ITA          13    Abruzzo            68
# 3    3  2020-02-24T18:00:00     ITA          13    Abruzzo            69
# 4    4  2020-02-24T18:00:00     ITA          13    Abruzzo           979
#
#                            ProvinceName ProvinceAbbreviation   Latitude  \
# 0                              L'Aquila                   AQ  42.351222
# 1                                Teramo                   TE  42.658918
# 2                               Pescara                   PE  42.464584
# 3                                Chieti                   CH  42.351032
# 4  In fase di definizione/aggiornamento                  NaN        NaN
#
#    Longitude  TotalPositiveCases
# 0  13.398438                   0
# ...

# %%
covid.tail(3)
# Out:
#          SNo                 Date Country  RegionCode RegionName  \
# 40198  40198  2020-12-06T17:00:00     ITA           5     Veneto
# 40199  40199  2020-12-06T17:00:00     ITA           5     Veneto
# 40200  40200  2020-12-06T17:00:00     ITA           5     Veneto
#
#        ProvinceCode                          ProvinceName  \
# 40198            29                                Rovigo
# 40199           899    Fuori Regione / Provincia Autonoma
# 40200           999  In fase di definizione/aggiornamento
#
#       ProvinceAbbreviation   Latitude  Longitude  TotalPositiveCases
# 40198                   RO  45.071073   11.79007                4577
# 40199                  NaN        NaN        NaN                2809
# 40200                  NaN        NaN        NaN                 403

# %%
covid.head(4)
# Out:
#    SNo                 Date Country  RegionCode RegionName  ProvinceCode  \
# 0    0  2020-02-24T18:00:00     ITA          13    Abruzzo            66
# 1    1  2020-02-24T18:00:00     ITA          13    Abruzzo            67
# 2    2  2020-02-24T18:00:00     ITA          13    Abruzzo            68
# 3    3  2020-02-24T18:00:00     ITA          13    Abruzzo            69
#
#   ProvinceName ProvinceAbbreviation   Latitude  Longitude  TotalPositiveCases
# 0     L'Aquila                   AQ  42.351222  13.398438                   0
# 1       Teramo                   TE  42.658918  13.704400                   0
# 2      Pescara                   PE  42.464584  14.213648                   0
# 3       Chieti                   CH  42.351032  14.167546                   0

# %%
covid
# Out:
#          SNo                 Date Country  RegionCode RegionName  \
# 0          0  2020-02-24T18:00:00     ITA          13    Abruzzo
# 1          1  2020-02-24T18:00:00     ITA          13    Abruzzo
# 2          2  2020-02-24T18:00:00     ITA          13    Abruzzo
# 3          3  2020-02-24T18:00:00     ITA          13    Abruzzo
# 4          4  2020-02-24T18:00:00     ITA          13    Abruzzo
# ...      ...                  ...     ...         ...        ...
# 40196  40196  2020-12-06T17:00:00     ITA           5     Veneto
# 40197  40197  2020-12-06T17:00:00     ITA           5     Veneto
# 40198  40198  2020-12-06T17:00:00     ITA           5     Veneto
# 40199  40199  2020-12-06T17:00:00     ITA           5     Veneto
# 40200  40200  2020-12-06T17:00:00     ITA           5     Veneto
#
#        ProvinceCode                          ProvinceName  \
# 0                66                              L'Aquila
# 1                67                                Teramo
# ...

# %%
covid.dtypes
# Out:
# SNo                       int64
# Date                     object
# Country                  object
# RegionCode                int64
# RegionName               object
# ProvinceCode              int64
# ProvinceName             object
# ProvinceAbbreviation     object
# Latitude                float64
# Longitude               float64
# TotalPositiveCases        int64
# dtype: object

# %%
covid.columms.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5068/3118714099.py in <module>
# ----> 1 covid.columms.values
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'columms'

# %%
covid.columns.values
# Out:
# array(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName',
#        'ProvinceCode', 'ProvinceName', 'ProvinceAbbreviation', 'Latitude',
#        'Longitude', 'TotalPositiveCases'], dtype=object)

# %%
covid.describe(include = 'all')
# Out:
#                  SNo                 Date Country    RegionCode RegionName  \
# count   40201.000000                40201   40201  40201.000000      40201
# unique           NaN                  287       1           NaN         21
# top              NaN  2020-07-16T17:00:00     ITA           NaN  Lombardia
# freq             NaN                  149   40201           NaN       3896
# mean    20100.000000                  NaN     NaN     10.357354        NaN
# std     11605.173423                  NaN     NaN      5.993795        NaN
# min         0.000000                  NaN     NaN      1.000000        NaN
# 25%     10050.000000                  NaN     NaN      5.000000        NaN
# 50%     20100.000000                  NaN     NaN      9.000000        NaN
# 75%     30150.000000                  NaN     NaN     16.000000        NaN
# max     40200.000000                  NaN     NaN     22.000000        NaN
#
#         ProvinceCode                          ProvinceName  \
# ...

# %%
covid.hist(figsize=(20,30))
# Out:
# array([[<AxesSubplot:title={'center':'SNo'}>,
#         <AxesSubplot:title={'center':'RegionCode'}>],
#        [<AxesSubplot:title={'center':'ProvinceCode'}>,
#         <AxesSubplot:title={'center':'Latitude'}>],
#        [<AxesSubplot:title={'center':'Longitude'}>,
#         <AxesSubplot:title={'center':'TotalPositiveCases'}>]],
#       dtype=object)

# %%
covid = covid.drop(['RegionCode', 'ProvinceCode'])
covid.head(5)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\sagar\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\sagar\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5068/2571025276.py in <module>
# ----> 1 covid = covid.drop(['RegionCode', 'ProvinceCode'])
#       2 covid.head(5)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# ...

# %%
covid.head(4)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\sagar\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\sagar\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\sagar\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\sagar\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
covid.head(5)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\sagar\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\sagar\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#    SNo                 Date Country  RegionCode RegionName  ProvinceCode  \
# 0    0  2020-02-24T18:00:00     ITA          13    Abruzzo            66
# 1    1  2020-02-24T18:00:00     ITA          13    Abruzzo            67
# 2    2  2020-02-24T18:00:00     ITA          13    Abruzzo            68
# 3    3  2020-02-24T18:00:00     ITA          13    Abruzzo            69
# 4    4  2020-02-24T18:00:00     ITA          13    Abruzzo           979
#
# ...

# %%
covid.head()
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\sagar\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\sagar\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#    SNo                 Date Country  RegionCode RegionName  ProvinceCode  \
# 0    0  2020-02-24T18:00:00     ITA          13    Abruzzo            66
# 1    1  2020-02-24T18:00:00     ITA          13    Abruzzo            67
# 2    2  2020-02-24T18:00:00     ITA          13    Abruzzo            68
# 3    3  2020-02-24T18:00:00     ITA          13    Abruzzo            69
# 4    4  2020-02-24T18:00:00     ITA          13    Abruzzo           979
#
# ...
